# %%
import pandas as pd
import numpy as np

# %%
url ='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv?raw=true'

# %%
fuel_data= pd.read_csv(url, error_bad_lines= False)

# %%
fuel_data.describe(include='all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_2016_12_132_0_1               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
fuel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.isnull().mean() * 100
# Out:
# record_id                       0.000000
# utility_id_ferc1                0.000000
# report_year                     0.000000
# plant_name_ferc1                0.000000
# fuel_type_code_pudl             0.000000
# fuel_unit                       0.609694
# fuel_qty_burned                 0.000000
# fuel_mmbtu_per_unit             0.000000
# fuel_cost_per_unit_burned       0.000000
# fuel_cost_per_unit_delivered    0.000000
# fuel_cost_per_mmbtu             0.000000
# dtype: float64

# %%
# Out:
# fuel_unit
# bbl       bblbblbblbblbblbblbblbblbblbblbblbblbblbblbblb...
# gal       galgalgalgalgalgalgalgalgalgalgalgalgalgalgalg...
# gramsU    gramsUgramsUgramsUgramsUgramsUgramsUgramsUgram...
# kgU       kgUkgUkgUkgUkgUkgUkgUkgUkgUkgUkgUkgUkgUkgUkgUk...
# mcf       mcfmcfmcfmcfmcfmcfmcfmcfmcfmcfmcfmcfmcfmcfmcfm...
# mmbtu     mmbtummbtummbtummbtummbtummbtummbtummbtummbtum...
# mwdth     mwdthmwdthmwdthmwdthmwdthmwdthmwdthmwdthmwdthm...
# mwhth     mwhthmwhthmwhthmwhthmwhthmwhthmwhthmwhthmwhthm...
# ton       tontontontontontontontontontontontontontontont...
# Name: fuel_unit, dtype: object

# %%
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29518    False
# 29519    False
# 29520    False
# 29521    False
# 29522    False
# Name: fuel_unit, Length: 29523, dtype: bool

# %%
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
# Out:
#                                   record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_1994_12_1_0_7                 1         1994
# gas                  f1_fuel_1994_12_2_0_10                 2         1994
# nuclear               f1_fuel_1994_12_2_1_1                 2         1994
# oil                   f1_fuel_1994_12_6_0_2                 6         1994
# other                f1_fuel_1994_12_11_0_6                11         1994
# waste                 f1_fuel_1994_12_9_0_3                 9         1994
#
#                      plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                         rockport       ton        5377489.0
# gas                         chickasaw       mcf          40533.0
# nuclear              joseph m. farley       kgU           2260.0
# oil                      clinch river       bbl           6510.0
# other                      w.f. wyman       bbl          55652.0
# ...

# %%
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
# Out:
#                  record_id  utility_id_ferc1  report_year plant_name_ferc1  \
# 0   f1_fuel_2009_12_79_0_2                79         2009         montrose
# 1   f1_fuel_2009_12_79_0_4                79         2009       hawthorn 5
# 2   f1_fuel_2009_12_79_0_5                79         2009       hawthorn 5
# 3   f1_fuel_2009_12_79_0_7                79         2009   hawthorn 6 & 9
# 4  f1_fuel_2009_12_79_0_10                79         2009   hawthorn 7 & 8
#
#   fuel_type_code_pudl fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0                 oil       bbl          22912.0             5.770422
# 1                coal       ton        2408123.0            16.782000
# 2                 gas       mcf          82141.0             1.000000
# 3                 gas       mcf        1701680.0             1.000000
# 4                 gas       mcf          82601.0             1.000000
#
#    fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# ...

# %%
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
pd.merge(fuel_df1, fuel_df2, how= 'outer')
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.duplicated().any()
# Out:
# False

# %%
fuel_data.groupby('fuel_cost_per_unit_burned').min()
# Out:
#                                           record_id  utility_id_ferc1  \
# fuel_cost_per_unit_burned
# -276.080                    f1_fuel_2000_12_194_3_3               194
# -174.670                    f1_fuel_2000_12_194_3_6               194
# -123.310                   f1_fuel_2000_12_194_2_15               194
# -119.040                    f1_fuel_2003_12_281_1_4               281
# -85.760                     f1_fuel_1995_12_194_5_9               194
# ...                                             ...               ...
#  65137.588                   f1_fuel_2012_12_7_7_13                 7
#  69785.215                   f1_fuel_2011_12_7_7_13                 7
#  80459.000                  f1_fuel_2014_12_177_2_7               177
#  83538.000                  f1_fuel_2011_12_132_1_2               132
#  139358.000                 f1_fuel_2014_12_147_0_2               147
#
#                            report_year     plant_name_ferc1  \
# fuel_cost_per_unit_burned
# ...

# %%
fuel_data['fuel_cost_per_unit_burned'].min()
# Out:
# -276.08

# %%
fuel_data[['fuel_type_code_pudl', 'fuel_qty_burned']].groupby(['fuel_type_code_pudl'], as_index=False).mean().sort_values(by='fuel_type_code_pudl',
ascending=True)
# Out:
#   fuel_type_code_pudl  fuel_qty_burned
# 0                coal     1.903473e+06
# 1                 gas     4.843183e+06
# 2             nuclear     5.454838e+06
# 3                 oil     6.311677e+04
# 4               other     2.948137e+06
# 5               waste     1.171914e+05

# %%
percentage_change= (1998-fuel_data['report_year'])
fuel_data.groupby(percentage_change)["fuel_qty_burned"].first()
# Out:
# report_year
# -20       2344.0
# -19       1054.0
# -18        949.0
# -17       2415.0
# -16     453825.0
# -15     484678.0
# -14     508138.0
# -13     392102.0
# -12     513861.0
# -11     551992.0
# -10     518267.0
# -9      152665.0
# -8      160919.0
# -7      673090.0
# -6     4629653.0
# -5      180788.0
# -4       82877.0
# -3       55679.0
# -2     2084751.0
# -1     2118951.0
#  0     4965881.0
#  1     5043970.0
#  2          34.0
#  3      327060.0
#  4     5377489.0
# Name: fuel_qty_burned, dtype: float64

# %%
fuel_data[['report_year', 'fuel_cost_per_unit_delivered']].groupby(['fuel_cost_per_unit_delivered'], as_index=False).max().sort_values(by='fuel_cost_per_unit_delivered',
ascending=True)
# Out:
#        fuel_cost_per_unit_delivered  report_year
# 0                          -874.937         2008
# 1                          -488.054         2007
# 2                          -313.410         2004
# 3                          -174.670         2000
# 4                          -170.187         2015
# ...                             ...          ...
# 16670                   1942979.000         1997
# 16671                   2114508.000         1996
# 16672                   2255688.000         1997
# 16673                   7793482.000         1996
# 16674                   7964521.000         1997
#
# [16675 rows x 2 columns]
